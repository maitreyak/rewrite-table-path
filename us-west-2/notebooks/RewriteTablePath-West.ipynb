# %%
from pyspark.sql import SparkSession
from pyspark import SparkConf

# %%
sp_conf = SparkConf() 
sp_conf.set("spark.sql.catalog.glue_catalog", "org.apache.iceberg.spark.SparkCatalog")
sp_conf.set("spark.sql.catalog.glue_catalog.warehouse", "s3://iceberg-wh-west/")
sp_conf.set("spark.sql.catalog.glue_catalog.catalog-impl", "org.apache.iceberg.aws.glue.GlueCatalog")
sp_conf.set("spark.sql.catalog.glue_catalog.io-impl", "org.apache.iceberg.aws.s3.S3FileIO")
sp_conf.set("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions")

# %%
spark = SparkSession.builder \
    .appName("Glue-Iceberg-Integration") \
    .config(conf=sp_conf) \
    .getOrCreate()
# Out:
# 25/08/02 20:17:14 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
spark.sql(f"""
  CALL glue_catalog.system.rewrite_table_path(
    table => 'berg.icetable1',
    source_prefix => 's3://iceberg-wh-west',
    target_prefix => 's3://iceberg-wh-east',
    staging_location => 's3a://iceberg-wh-west/berg.db/icetable1/staging_east_metadata'
  )
""")

# %%
spark.sql("""
    CREATE DATABASE IF NOT EXISTS glue_catalog.berg 
""")
# Out:
# DataFrame[]

# %%
spark.sql("select count(*) from glue_catalog.berg.icetable1").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |     300|
# +--------+

# %%
import random
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

write_to_db = "berg"
write_to_table = "icetable1"

data = [(i, f"name_{random.randint(1000, 9999)}") for i in range(100)]

# Step 2: Create DataFrame with schema id(int), name(string)
schema = StructType([
    StructField("id", IntegerType(), False),
    StructField("name", StringType(), False)
])
df = spark.createDataFrame(data, schema)

df.createOrReplaceTempView("temp_table1")

df.show()

spark.sql(f"""
    INSERT INTO glue_catalog.{write_to_db}.{write_to_table}
    SELECT id, name FROM temp_table1
""")
# Out:
# +---+---------+
# | id|     name|
# +---+---------+
# |  0|name_2035|
# |  1|name_6140|
# |  2|name_5277|
# |  3|name_4601|
# |  4|name_1646|
# |  5|name_3085|
# |  6|name_3107|
# |  7|name_9353|
# |  8|name_1659|
# |  9|name_4114|
# | 10|name_8145|
# | 11|name_6816|
# | 12|name_2026|
# | 13|name_5889|
# | 14|name_9802|
# | 15|name_3176|
# | 16|name_2154|
# | 17|name_6764|
# | 18|name_3404|
# | 19|name_3525|
# +---+---------+
# only showing top 20 rows
# DataFrame[]

# %%
spark.sql("select count(*) from glue_catalog.berg.icetable1").show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |     600|
# +--------+

# %%
spark.sql("""
  CALL glue_catalog.system.rewrite_table_path(
    table => 'berg.icetable1',
    source_prefix => 's3://iceberg-wh-west',
    target_prefix => 's3://iceberg-wh-east',
    staging_location => 's3a://iceberg-wh-west/berg.db/icetable1/staging_east_metadata'
  )
""")
# Out:
# 25/08/03 01:31:02 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 25/08/03 01:31:03 WARN AbstractS3ACommitterFactory: Using standard FileOutputCommitter to commit work. This is slow and potentially unsafe.
# 25/08/03 01:31:04 WARN AbstractS3ACommitterFactory: Using standard FileOutputCommitter to commit work. This is slow and potentially unsafe.
# DataFrame[latest_version: string, file_list_location: string]

# %%
import boto3
def active_iceberg_table_metadata(active_database_name, active_table_name):
    glue = boto3.client("glue", region_name = 'us-west-2')
    table = glue.get_table(DatabaseName=active_database_name, Name=active_table_name)
    parameters = table["Table"]["Parameters"]
    full_path_metadata_location = parameters["metadata_location"]
    return full_path_metadata_location.split('/')[-1]

print(active_iceberg_table_metadata("berg", "icetable1"))
# Out:
# 00003-19cbcc94-a339-4934-949d-888a57eeb46f.metadata.json

# %%
# Create a DynamoDB resource

def get_lastest_metadata(db, tablename):
    dynamodb = boto3.resource('dynamodb', region_name='us-west-2')
    # Get a table resource
    table = dynamodb.Table('latest_metadata')
    key = {'dbtable': f"{db}.{tablename}"}
    try:
        response = table.get_item(Key = key)
        return response["Item"]["metadatafile"]
    except Exception as e:
        print("Error getting item:", e)
# Out:
# 00006-a98730a9-ef2e-498f-a370-63e2f1794105.metadata.json

# %%
def update_iceberg_table_metadata(active_database_name, active_table_name, metadata):
    glue = boto3.client("glue", region_name = 'us-west-2')
    table = glue.get_table(DatabaseName=active_database_name, Name=active_table_name)
    table_input = table["Table"]
    table_input["Parameters"]["metadata_location"] = f"s3://iceberg-wh-west/berg.db/icetable1/metadata/{metadata}"
    
    keys_to_remove = ['CreateTime', 'UpdateTime', 'IsRegisteredWithLakeFormation', 'CatalogId', 'DatabaseName', 'CreatedBy', 'VersionId', 'IsMultiDialectView']
    
    for key in keys_to_remove:
        if key in table_input: del table_input[key]

    print(table_input)
    glue.update_table(
        DatabaseName=active_database_name,
        TableInput=table_input
    )
    return
update_iceberg_table_metadata("berg", "icetable1", get_lastest_metadata("berg", "icetable1"))
# Out:
# {'Name': 'icetable1', 'Retention': 0, 'StorageDescriptor': {'Columns': [{'Name': 'id', 'Type': 'int', 'Parameters': {'iceberg.field.current': 'true', 'iceberg.field.id': '1', 'iceberg.field.optional': 'true'}}, {'Name': 'name', 'Type': 'string', 'Parameters': {'iceberg.field.current': 'true', 'iceberg.field.id': '2', 'iceberg.field.optional': 'true'}}], 'Location': 's3://iceberg-wh-west/berg.db/icetable1', 'AdditionalLocations': [], 'Compressed': False, 'NumberOfBuckets': 0, 'SortColumns': [], 'StoredAsSubDirectories': False}, 'TableType': 'EXTERNAL_TABLE', 'Parameters': {'metadata_location': 's3://iceberg-wh-west/berg.db/icetable1/metadata/00006-a98730a9-ef2e-498f-a370-63e2f1794105.metadata.json', 'previous_metadata_location': 's3://iceberg-wh-west/berg.db/icetable1/metadata/00002-16fa8b62-7251-4eed-8e6c-c97d2e2594fa.metadata.json', 'table_type': 'ICEBERG'}}

# %%
# !aws s3 sync s3://iceberg-wh-west/berg.db/icetable1/staging_west_metadata  s3://iceberg-wh-west/berg.db/icetable1/metadata --exclude file-list
# Out:
# copy: s3://iceberg-wh-west/berg.db/icetable1/staging_west_metadata/00000-a965cd33-3b31-4f67-97df-7bf089f8e25f.metadata.json to s3://iceberg-wh-west/berg.db/icetable1/metadata/00000-a965cd33-3b31-4f67-97df-7bf089f8e25f.metadata.json
# copy: s3://iceberg-wh-west/berg.db/icetable1/staging_west_metadata/87cbd86f-d320-4d0a-ad8a-9f01f1e8e7b3-m0.avro to s3://iceberg-wh-west/berg.db/icetable1/metadata/87cbd86f-d320-4d0a-ad8a-9f01f1e8e7b3-m0.avro
# copy: s3://iceberg-wh-west/berg.db/icetable1/staging_west_metadata/00002-16fa8b62-7251-4eed-8e6c-c97d2e2594fa.metadata.json to s3://iceberg-wh-west/berg.db/icetable1/metadata/00002-16fa8b62-7251-4eed-8e6c-c97d2e2594fa.metadata.json
# copy: s3://iceberg-wh-west/berg.db/icetable1/staging_west_metadata/00006-a98730a9-ef2e-498f-a370-63e2f1794105.metadata.json to s3://iceberg-wh-west/berg.db/icetable1/metadata/00006-a98730a9-ef2e-498f-a370-63e2f1794105.metadata.json
# copy: s3://iceberg-wh-west/berg.db/icetable1/staging_west_metadata/00003-19cbcc94-a339-4934-949d-888a57eeb46f.metadata.json to s3://iceberg-wh-west/berg.db/icetable1/metadata/00003-19cbcc94-a339-4934-949d-888a57eeb46f.metadata.json
# copy: s3://iceberg-wh-west/berg.db/icetable1/staging_west_metadata/00004-bafdff20-352d-4b17-89ae-a75eda17bd3c.metadata.json to s3://iceberg-wh-west/berg.db/icetable1/metadata/00004-bafdff20-352d-4b17-89ae-a75eda17bd3c.metadata.json
# copy: s3://iceberg-wh-west/berg.db/icetable1/staging_west_metadata/00005-90e7e796-12d5-4ae4-b90f-768c062d734a.metadata.json to s3://iceberg-wh-west/berg.db/icetable1/metadata/